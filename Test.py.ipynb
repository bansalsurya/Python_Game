# %%
import pygame
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# !pip install pygame

# %%
import pygame

# %%
pygame.display.set_mode(size=(1000,600),display=1)
# Out:
# <Surface(1000x600x32 SW)>
