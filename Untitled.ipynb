# %%
! pip install jythemes
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000008B29535508>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/jythemes/
#   ERROR: Could not find a version that satisfies the requirement jythemes (from versions: none)
# ERROR: No matching distribution found for jythemes

# %%
data = pd.read_excel("Data.xlsx")

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.add(name+" "+age+" "+score)
