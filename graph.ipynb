# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data.csv",header=None)
df
# Out:
#             0    1    2  3
# 0       swati   18   81  3
# 1       vansh   12   14  1
# 2      nikhil   21    3  1
# 3      nikhil   19   48  2
# 4       surya   19   67  2
# 5         nik   90    0  1
# 6     ujjawal   50   24  1
# 7      rajeev   45   97  3
# 8       rekha   67    2  1
# 9      pragya   89   12  1
# 10    shubham   78   29  1
# 11      payal   77   95  3
# 12     mayank   66   16  1
# 13      rishi   55   32  1
# 14      nisha   87  173  5
# 15    archana   45    2  1
# 16      mohit   81    2  1
# 17     danish   75   62  2
# 18    rajeevv   89   45  2
# 19     hitesh   78   70  2
# 20     prachi   67  107  3
# 21  pratiksha   71   32  1
# 22     ashish   78  156  4
# 23    rishabh   70    5  1
# 24     hritik   88  120  4
# 25      nitin   69  144  4
# 26    akansha   88   17  1
# 27      aryan   99   45  2
# 28     akshat   87   69  2
# 29    neetika  100   99  3
# 30     manali   66   92  3
# 31     shivam   54   83  3
# 32     sanaya   78  212  6
# 33     akshat   77   34  1
# 34     akshay   90   95  3
# 35     pulkit   69   12  1
# 36   shrikant   61    0  1
# 37     deepak   87   10  1
# 38       vani   77    4  1
# 39      ritik   71   17  1
# 40   priyanka   65   36  1

# %%
df.shape
# Out:
# (41, 4)

# %%
narr = np.array(df)

# %%
narr
# Out:
# array([['swati', 18, 81, 3],
#        ['vansh', 12, 14, 1],
#        ['nikhil', 21, 3, 1],
#        ['nikhil', 19, 48, 2],
#        ['surya', 19, 67, 2],
#        ['nik', 90, 0, 1],
#        ['ujjawal', 50, 24, 1],
#        ['rajeev', 45, 97, 3],
#        ['rekha', 67, 2, 1],
#        ['pragya', 89, 12, 1],
#        ['shubham', 78, 29, 1],
#        ['payal', 77, 95, 3],
#        ['mayank', 66, 16, 1],
#        ['rishi', 55, 32, 1],
#        ['nisha', 87, 173, 5],
#        ['archana', 45, 2, 1],
#        ['mohit', 81, 2, 1],
#        ['danish', 75, 62, 2],
#        ['rajeevv', 89, 45, 2],
#        ['hitesh', 78, 70, 2],
#        ['prachi', 67, 107, 3],
#        ['pratiksha', 71, 32, 1],
#        ['ashish', 78, 156, 4],
#        ['rishabh', 70, 5, 1],
#        ['hritik', 88, 120, 4],
#        ['nitin', 69, 144, 4],
#        ['akansha', 88, 17, 1],
#        ['aryan', 99, 45, 2],
#        ['akshat', 87, 69, 2],
#        ['neetika', 100, 99, 3],
#        ['manali', 66, 92, 3],
#        ['shivam', 54, 83, 3],
#        ['sanaya', 78, 212, 6],
#        ['akshat', 77, 34, 1],
#        ['akshay', 90, 95, 3],
#        ['pulkit', 69, 12, 1],
#        ['shrikant', 61, 0, 1],
#        ['deepak', 87, 10, 1],
#        ['vani', 77, 4, 1],
#        ['ritik', 71, 17, 1],
#        ['priyanka', 65, 36, 1]], dtype=object)

# %%
y=narr[ : ,2]
x=narr[ : ,1]
plt.scatter(x,y)

# %%
narr
# Out:
# array([['swati', 18, 81, 3],
#        ['vansh', 12, 14, 1],
#        ['nikhil', 21, 3, 1],
#        ['nikhil', 19, 48, 2],
#        ['surya', 19, 67, 2],
#        ['nik', 90, 0, 1],
#        ['ujjawal', 50, 24, 1],
#        ['rajeev', 45, 97, 3],
#        ['rekha', 67, 2, 1],
#        ['pragya', 89, 12, 1],
#        ['shubham', 78, 29, 1],
#        ['payal', 77, 95, 3],
#        ['mayank', 66, 16, 1],
#        ['rishi', 55, 32, 1],
#        ['nisha', 87, 173, 5],
#        ['archana', 45, 2, 1],
#        ['mohit', 81, 2, 1],
#        ['danish', 75, 62, 2],
#        ['rajeevv', 89, 45, 2],
#        ['hitesh', 78, 70, 2],
#        ['prachi', 67, 107, 3],
#        ['pratiksha', 71, 32, 1],
#        ['ashish', 78, 156, 4],
#        ['rishabh', 70, 5, 1],
#        ['hritik', 88, 120, 4],
#        ['nitin', 69, 144, 4],
#        ['akansha', 88, 17, 1],
#        ['aryan', 99, 45, 2],
#        ['akshat', 87, 69, 2],
#        ['neetika', 100, 99, 3],
#        ['manali', 66, 92, 3],
#        ['shivam', 54, 83, 3],
#        ['sanaya', 78, 212, 6],
#        ['akshat', 77, 34, 1],
#        ['akshay', 90, 95, 3],
#        ['pulkit', 69, 12, 1],
#        ['shrikant', 61, 0, 1],
#        ['deepak', 87, 10, 1],
#        ['vani', 77, 4, 1],
#        ['ritik', 71, 17, 1],
#        ['priyanka', 65, 36, 1]], dtype=object)

# %%
narr[:,1] = narr[:,1]-35

# %%
narr
# Out:
# array([['swati', -17, 81, 3],
#        ['vansh', -23, 14, 1],
#        ['nikhil', -14, 3, 1],
#        ['nikhil', -16, 48, 2],
#        ['surya', -16, 67, 2],
#        ['nik', 55, 0, 1],
#        ['ujjawal', 15, 24, 1],
#        ['rajeev', 10, 97, 3],
#        ['rekha', 32, 2, 1],
#        ['pragya', 54, 12, 1],
#        ['shubham', 43, 29, 1],
#        ['payal', 42, 95, 3],
#        ['mayank', 31, 16, 1],
#        ['rishi', 20, 32, 1],
#        ['nisha', 52, 173, 5],
#        ['archana', 10, 2, 1],
#        ['mohit', 46, 2, 1],
#        ['danish', 40, 62, 2],
#        ['rajeevv', 54, 45, 2],
#        ['hitesh', 43, 70, 2],
#        ['prachi', 32, 107, 3],
#        ['pratiksha', 36, 32, 1],
#        ['ashish', 43, 156, 4],
#        ['rishabh', 35, 5, 1],
#        ['hritik', 53, 120, 4],
#        ['nitin', 34, 144, 4],
#        ['akansha', 53, 17, 1],
#        ['aryan', 64, 45, 2],
#        ['akshat', 52, 69, 2],
#        ['neetika', 65, 99, 3],
#        ['manali', 31, 92, 3],
#        ['shivam', 19, 83, 3],
#        ['sanaya', 43, 212, 6],
#        ['akshat', 42, 34, 1],
#        ['akshay', 55, 95, 3],
#        ['pulkit', 34, 12, 1],
#        ['shrikant', 26, 0, 1],
#        ['deepak', 52, 10, 1],
#        ['vani', 42, 4, 1],
#        ['ritik', 36, 17, 1],
#        ['priyanka', 30, 36, 1]], dtype=object)

# %%
narr[:5,1]=narr[:5,1]+35

# %%
narr
# Out:
# array([['swati', 18, 81, 3],
#        ['vansh', 12, 14, 1],
#        ['nikhil', 21, 3, 1],
#        ['nikhil', 19, 48, 2],
#        ['surya', 19, 67, 2],
#        ['nik', 55, 0, 1],
#        ['ujjawal', 15, 24, 1],
#        ['rajeev', 10, 97, 3],
#        ['rekha', 32, 2, 1],
#        ['pragya', 54, 12, 1],
#        ['shubham', 43, 29, 1],
#        ['payal', 42, 95, 3],
#        ['mayank', 31, 16, 1],
#        ['rishi', 20, 32, 1],
#        ['nisha', 52, 173, 5],
#        ['archana', 10, 2, 1],
#        ['mohit', 46, 2, 1],
#        ['danish', 40, 62, 2],
#        ['rajeevv', 54, 45, 2],
#        ['hitesh', 43, 70, 2],
#        ['prachi', 32, 107, 3],
#        ['pratiksha', 36, 32, 1],
#        ['ashish', 43, 156, 4],
#        ['rishabh', 35, 5, 1],
#        ['hritik', 53, 120, 4],
#        ['nitin', 34, 144, 4],
#        ['akansha', 53, 17, 1],
#        ['aryan', 64, 45, 2],
#        ['akshat', 52, 69, 2],
#        ['neetika', 65, 99, 3],
#        ['manali', 31, 92, 3],
#        ['shivam', 19, 83, 3],
#        ['sanaya', 43, 212, 6],
#        ['akshat', 42, 34, 1],
#        ['akshay', 55, 95, 3],
#        ['pulkit', 34, 12, 1],
#        ['shrikant', 26, 0, 1],
#        ['deepak', 52, 10, 1],
#        ['vani', 42, 4, 1],
#        ['ritik', 36, 17, 1],
#        ['priyanka', 30, 36, 1]], dtype=object)

# %%
y=narr[ : ,2]
x=narr[ : ,1]
plt.scatter(x,y)

# %%
threshold = np.mean(narr[:,2])

# %%
threshold
# Out:
# 55.19512195121951

# %%
np.std(narr[:,2])
# Out:
# 52.22055455151787

# %%
import math

# %%
math.sqrt((1/(narr.shape[0]))*(narr[:,2]-threshold)**2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-a304c5accbd6> in <module>
# ----> 1 math.sqrt((1/(narr.shape[0]))*(narr[:,2]-threshold)**2)
#
# TypeError: only size-1 arrays can be converted to Python scalars
